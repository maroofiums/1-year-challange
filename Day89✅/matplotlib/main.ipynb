# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0,11)
y = np.arange(0,11)

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 11 artists>

# %%
data = np.random.randint(0,30,10)

# %%
plt.hist(data)
# Out:
# (array([2., 0., 1., 0., 2., 0., 2., 1., 1., 1.]),
#  array([ 3. ,  4.9,  6.8,  8.7, 10.6, 12.5, 14.4, 16.3, 18.2, 20.1, 22. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pie(data)
# Out:
# ([<matplotlib.patches.Wedge at 0x138650714f0>,
# ...
#  [Text(1.060765362537315, 0.2911646366595345, ''),
#   Text(0.5730343561367323, 0.9389524091704333, ''),
#   Text(-0.5029665939762922, 0.9782763440582052, ''),
#   Text(-0.9843281979640972, 0.49101730997262527, ''),
#   Text(-1.0970655054737295, -0.08029493570375913, ''),
#   Text(-0.6828425055870808, -0.8623955661780489, ''),
#   Text(-0.2260817388064892, -1.076516162153748, ''),
#   Text(0.1734008390777356, -1.086246817720143, ''),
#   Text(0.8192494717428137, -0.7340506134110377, ''),
#   Text(1.0840549240019082, -0.18661436640092155, '')])
