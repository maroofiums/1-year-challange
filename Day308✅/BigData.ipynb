# %%
# !pip install pystark
# Out:
# Collecting pystark
#   Downloading PyStark-1.2.0.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyrogram==1.* (from pystark)
#   Downloading Pyrogram-1.4.16-py3-none-any.whl.metadata (4.4 kB)
# Collecting TgCrypto>=1.2.3 (from pystark)
#   Downloading TgCrypto-1.2.5.tar.gz (37 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: python-dotenv>=0.19.2 in /usr/local/lib/python3.12/dist-packages (from pystark) (1.2.1)
# Requirement already satisfied: pytz>=2021.3 in /usr/local/lib/python3.12/dist-packages (from pystark) (2025.2)
# Requirement already satisfied: sqlalchemy>=1.4.34 in /usr/local/lib/python3.12/dist-packages (from pystark) (2.0.46)
# Requirement already satisfied: psycopg2>=2.9.3 in /usr/local/lib/python3.12/dist-packages (from pystark) (2.9.11)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from pystark) (6.0.3)
# Collecting pyaes==1.6.1 (from pyrogram==1.*->pystark)
#   Downloading pyaes-1.6.1.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pysocks==1.7.1 in /usr/local/lib/python3.12/dist-packages (from pyrogram==1.*->pystark) (1.7.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.34->pystark) (3.3.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.34->pystark) (4.15.0)
# Downloading Pyrogram-1.4.16-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 48.8 MB/s eta 0:00:00
# Building wheels for collected packages: pystark, pyaes, TgCrypto
#   Building wheel for pystark (setup.py) ... done
#   Created wheel for pystark: filename=PyStark-1.2.0-py3-none-any.whl size=64435 sha256=ecf572cfb9f093474c767337dde30c265e7462093fea97bed436e8d0070acbce
#   Stored in directory: /root/.cache/pip/wheels/d3/2e/7d/395401bf8d2220663b8c8301139fc9e2bc885c96e0c2443863
#   Building wheel for pyaes (setup.py) ... done
#   Created wheel for pyaes: filename=pyaes-1.6.1-py3-none-any.whl size=26347 sha256=9b8548a768b19cc2268708cb84ed1a1f3051eec8d43e471fdde84de8ba711f3b
#   Stored in directory: /root/.cache/pip/wheels/d9/43/32/ec313dd557e88e419489b9df40c04dad7b99576bde162496f8
#   Building wheel for TgCrypto (pyproject.toml) ... done
#   Created wheel for TgCrypto: filename=tgcrypto-1.2.5-cp312-cp312-linux_x86_64.whl size=58716 sha256=62e0c783a0019f8b2d3f2ca656f67198bb71ee908391f9f033b5b573ccda8d62
#   Stored in directory: /root/.cache/pip/wheels/38/fd/41/685ff3dc08fc7a366ab3a5625966cc21fb06333451901e6ed3
# Successfully built pystark pyaes TgCrypto
# Installing collected packages: pyaes, TgCrypto, pyrogram, pystark
# Successfully installed TgCrypto-1.2.5 pyaes-1.6.1 pyrogram-1.4.16 pystark-1.2.0

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg

# %%
spark = SparkSession.builder \
        .appName("BigDataDemo") \
        .master("local[*]") \
        .getOrCreate()

# %%
data = [
    ("Alice", 25, "USA"),
    ("Bob", 30, "UK"),
    ("Charlie", 35, "USA"),
    ("David", 40, "India"),
    ("Eve", 28, "UK")
]

columns = ["Name", "Age", "Country"]

df = spark.createDataFrame(data, columns)
df.show()
# Out:
# +-------+---+-------+
# |   Name|Age|Country|
# +-------+---+-------+
# |  Alice| 25|    USA|
# |    Bob| 30|     UK|
# |Charlie| 35|    USA|
# |  David| 40|  India|
# |    Eve| 28|     UK|
# +-------+---+-------+

# %%
df.filter(col("Age") > 30).show()
# Out:
# +-------+---+-------+
# |   Name|Age|Country|
# +-------+---+-------+
# |Charlie| 35|    USA|
# |  David| 40|  India|
# +-------+---+-------+

# %%
df.groupBy("Country").agg(avg("Age").alias("Average_Age")).show()
# Out:
# +-------+-----------+
# |Country|Average_Age|
# +-------+-----------+
# |    USA|       30.0|
# |     UK|       29.0|
# |  India|       40.0|
# +-------+-----------+

# %%
df = df.withColumn("AgePlusTen", col("Age") + 10)
df.show()
# Out:
# +-------+---+-------+----------+
# |   Name|Age|Country|AgePlusTen|
# +-------+---+-------+----------+
# |  Alice| 25|    USA|        35|
# |    Bob| 30|     UK|        40|
# |Charlie| 35|    USA|        45|
# |  David| 40|  India|        50|
# |    Eve| 28|     UK|        38|
# +-------+---+-------+----------+

# %%
spark.stop()
